# %%
import pandas as pd
import numpy as np
from plotnine import *

# %%
df = pd.read_sas(r'C:\Users\1000257489\Documents\2022\Programs\20220915 Media Bay 3 Bin\0920\test.csv')
df.shape
# Out:
# (150, 7)

# %%
df.head()
# Out:
#   Sputter_WK                         RMK_  _FREQ_  s904_ser_roller_ma_std  \
# 0    2021WK0   GC5_PHO_2bin_BadBay_BFWK26     243                4.197531
# 1    2021WK0  GC5_PHO_2bin_GoodBay_BFWK26    2088                3.974108
# 2   2021WK33  GC5_PHO_2bin_GoodBay_BFWK26    4408                4.411479
# 3   2021WK34  GC5_PHO_2bin_GoodBay_BFWK26     163                3.987578
# 4   2021WK35   GC5_PHO_2bin_BadBay_BFWK26      46                5.217391
#
#    TSE2_FR  DET_OWP_P5  DET_OWP
# 0      0.0   26.226801     26.2
# 1      0.0   26.367800     26.4
# 2      0.0   26.448400     26.4
# 3      0.0   26.487801     26.4
# 4      0.0   27.417500     27.4

# %%
p = (ggplot(df)
#      + geom_point(shape='.', size=4)
#      + geom_line()
     + geom_density(data=df, mapping=aes(x='_FREQ_', fill='RMK_'), bw=1, color='k', alpha=1, size=0.25, kernel='Gaussian')
     + theme_matplotlib()
     + theme(figure_size=(6, 4))
    )
print(p)
# Out:
# C:\Users\1000257489\Anaconda3\lib\site-packages\plotnine\stats\stat_density.py:215: RuntimeWarning: invalid value encountered in divide
# C:\Users\1000257489\Anaconda3\lib\site-packages\plotnine\stats\stat_density.py:215: RuntimeWarning: invalid value encountered in divide
# C:\Users\1000257489\Anaconda3\lib\site-packages\plotnine\stats\stat_density.py:215: RuntimeWarning: invalid value encountered in divide
